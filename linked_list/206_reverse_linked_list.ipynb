# %% [markdown]
# ![image.png](attachment:image.png)

# %%
from typing import Optional
# Definition for singly-linked list.
class ListNode:
    def __init__(self, val=0, next=None):
        self.val = val
        self.next = next

class Solution:
    def reverseList(self, head: Optional[ListNode]) ->Optional[ListNode]:
        if head == None or head.next == None:
            return head

        pre = None
        curr = head
        while curr!=None:
            next = curr.next
            curr.next = pre
            pre = curr
            curr = next

        return pre

# %%
def create_linked_list(values):
    if not values:
        return None
    head = ListNode(values[0])
    current = head
    for value in values[1:]:
        current.next = ListNode(value)
        current = current.next
    return head

# 示例链表: [1, 2, 3, 4, 5]
head = create_linked_list([1, 2, 3, 4, 5])

# %%
solution = Solution()
new_head = solution.reverseList(head)

# %%
def print_linked_list(head):
    current = head
    while current:
        print(current.val, end=" -> " if current.next else "\n")
        current = current.next

print_linked_list(new_head)
# Out:
# 5 -> 4 -> 3 -> 2 -> 1

# %%
head = create_linked_list([1, 2, 3, 4, 5])
pre = None
curr = head
print(f"In the beginning: ")
print(f"Current node value: {curr.val}")
# Out:
# In the beginning:
# Current node value: 1

# %%
while curr!=None:
    print(f"In the beginning: ")
    print(f"Current node value: {curr.val}")

    next = curr.next
    if next:
        print(f"Next node value: {next.val}")
    else:
        print("Next node is None")
    curr.next = pre
    print(f"now curr is :{curr.val}")
    if curr.next:
        
        print(f"curr.next is :{curr.next.val}")
    pre = curr
    print(f"Pre is now: {pre.val}")
    curr = next
    if curr:
        print(f"Moving to next node with value: {curr.val}")
    else:
        print("Current node is now None (end of list)")
# Out:
# In the beginning:
# Current node value: 1
# Next node value: 2
# now curr is :1
# Pre is now: 1
# Moving to next node with value: 2
# In the beginning:
# Current node value: 2
# Next node value: 3
# now curr is :2
# curr.next is :1
# Pre is now: 2
# Moving to next node with value: 3
# In the beginning:
# Current node value: 3
# Next node value: 4
# now curr is :3
# curr.next is :2
# Pre is now: 3
# Moving to next node with value: 4
# In the beginning:
# Current node value: 4
# Next node value: 5
# now curr is :4
# curr.next is :3
# Pre is now: 4
# Moving to next node with value: 5
# In the beginning:
# Current node value: 5
# Next node is None
# now curr is :5
# curr.next is :4
# Pre is now: 5
# Current node is now None (end of list)
